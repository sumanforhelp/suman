# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

def model(N(t),t):
    dNt = -k*.
    return dydt

y0=0
t=np.linspace(0,5)
y=odeint(model,y0,t)

plt.plot(t,y)
plt.xlabel('time')
plt.ylabel('y')
plt.show()
